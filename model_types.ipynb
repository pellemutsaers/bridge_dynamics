# %% [markdown]
# MCFM -> The moving constant force model
# MHFM -> The moving harmonic force model
# MMM -> moving mass model
# MSDMM -> The moving spring-damping-mass model
# TAVBM -> two-axle vehicle-bridge model
# TBDIM -> train–bridge dynamic interaction model
# TTBDIM -> train–track-bridge dynamic interaction model

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# MCFM: \
# ![image.png](attachment:image.png)
